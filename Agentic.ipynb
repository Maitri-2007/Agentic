# %% [markdown]
# GETTING STARTED WITH BASICS

# %%
google_api_key = os.getenv('google_API_KEY') 

if google_api_key:
    print(f"google API Key exists and begins {google_api_key[:8]}")
else:
    print("google API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# google API Key exists and begins AQ.Ab8RN

# %%
from dotenv import load_dotenv
from openai import OpenAI  # openai is the library  and  OpenAI is class inside that library

import os

load_dotenv(override=True)

client = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
messages = [{"role": "user", "content": "What is 2+2?"}]

response = client.chat.completions.create(
    model="gemini-3.7-flash",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %% [markdown]
# CHOOSING A FIELD, FINDING ITS MAJOR PAINPOINT AND A PROPOSED SITUATION

# %%
from IPython.display import display, Markdown

question="pick a bussiness sector in any field of interest"
messages = [{"role": "user", "content": question}]

response = client.chat.completions.create(
    model="gemini-3.5-flash-lite",
    messages=messages
)

ans=response.choices[0].message.content

display(Markdown(ans))
# Out:
# Let's go with the **Space Economy (Commercial Aerospace & Space Tech)**.
#
# It is one of the most futuristic, rapidly growing, and high-stakes sectors right now, bridging heavy engineering, artificial intelligence, global logistics, and environmental science.
#
# If we were to zoom in on a specific business model within this sector, what would you like to explore?
# 1. **Space Tourism & Hospitality** (Orbital hotels, zero-g experiences)
# 2. **Satellite-as-a-Service (SaaS)** (Earth observation, climate tracking, agricultural data)
# 3. **Asteroid Mining & Resource Extraction** (In-situ resource utilization)
# 4. **Space Debris Removal** (Orbital cleanup and sustainability)

# %%
ans=response.choices[0].message.content

question = f"in the bussiness sector: {ans}- what is a major pain point in that bussiness sector?"
messages = [{"role": "user", "content": question}]

response = client.chat.completions.create(
    model="gemini-3.5-flash-lite",
    messages=messages
)

pain = response.choices[0].message.content
display(Markdown(pain))
display(Markdown(ans))
# Out:
# If we zoom in on **4. Space Debris Removal (Orbital Cleanup & Sustainability)**, we are looking at one of the most intellectually fascinating businesses in the world right now: garbage collection, but at 17,500 miles per hour in a vacuum.
#
# While there are many challenges (technical, legal, and financial), the **single greatest pain point** in the space debris removal sector is:
#
# ### **The "Orphan Asset" Problem (The Free-Rider Dilemma & Lack of a Payer)**
#
# To put it bluntly: **Space debris is a massive tragedy of the commons, and right now, nobody is legally required to pay to clean up their mess.**
#
# Here is why this is a nightmare for a business model:
#
# #### 1. The Economics Don't Close (Yet)
# If a company builds an expensive piece of orbital hardware—say, a "space tug" with robotic arms or a harpoon system—to capture and de-orbit a dead rocket booster, **who pays the invoice?**
# ...

# %%
pain = response.choices[0].message.content

question = f"in the bussiness sector for: {pain}- propose a detailed solution to solve this problem"
messages = [{"role": "user", "content": question}]

response = client.chat.completions.create(
    model="gemini-3.5-flash-lite",
    messages=messages
)

solution = response.choices[0].message.content
display(Markdown(solution))
# Out:
# To solve the **"Orphan Asset" Problem** in Space Debris Removal, a startup must accept a hard economic reality: **You cannot build a pure "garbage collection" business today.** Just as municipal waste management only works when backed by municipal tax authorities or mandatory sanitation laws, orbital debris removal requires a systemic financial and legal bridge to survive until global mandates catch up.
#
# Here is a detailed, multi-layered business and financial architecture designed to bypass the Orphan Asset Problem and build a viable, venture-backable enterprise.
#
# ---
#
# ### The Solution: The "Trojan Horse" Hybrid Model
#
# To solve the lack of a direct payer for orphan debris, the startup must deploy a three-stage revenue and operational architecture: **In-Orbit Servicing (ISAM) as the Cash Cow, Sovereign/ESG Bonds for the Orphan Debris, and Dynamic Insurance-Linked Pricing.**
#
# ---
#
# ...

# %% [markdown]
# GENERATING A GRADE 8 MATH PROBLEM, SOLVING IT AND CHECKING IF THE SOLUTION IS CORRECT

# %%
question = "generate a grade 8 math word problem, give only question"
messages = [{"role": "user", "content": question}]

response = client.chat.completions.create(
    model="gemini-3.5-flash-lite",
    messages=messages
)

problem = response.choices[0].message.content
display(Markdown(problem))
# Out:
# Sarah is baking cookies for a school fundraiser and needs to use a recipe that calls for $2\frac{1}{4}$ cups of flour to make 18 cookies. If she wants to make 54 cookies, how many cups of flour will she need?

# %%
problem = response.choices[0].message.content
question = f"for the word problem: {problem}- give a detailed solution"
messages = [{"role": "user", "content": question}]

response = client.chat.completions.create(
    model="gemini-3.5-flash-lite",
    messages=messages
)

solution = response.choices[0].message.content
display(Markdown(solution))
# Out:
# Here is a detailed, step-by-step solution to the word problem:
#
# ### **Problem Statement:**
# Sarah is baking cookies for a school fundraiser and needs to use a recipe that calls for $2\frac{1}{4}$ cups of flour to make 18 cookies. If she wants to make 54 cookies, how many cups of flour will she need?
#
# ---
#
# ### **Detailed Solution:**
#
# #### **Step 1: Understand the goal**
# We need to find out how many cups of flour are required to make 54 cookies, given that $2\frac{1}{4}$ cups of flour make 18 cookies.
#
# #### **Step 2: Find the scaling factor**
# First, let's figure out how many times larger the new batch of cookies is compared to the original recipe. We do this by dividing the desired number of cookies by the original number of cookies:
#
# $$\text{Scaling Factor} = \frac{\text{Desired cookies}}{\text{Original cookies}}$$
#
# $$\text{Scaling Factor} = \frac{54}{18}$$
#
# If we calculate this division:
# $$18 \times 3 = 54$$
# ...

# %%
solution = response.choices[0].message.content
problem = response.choices[0].message.content

question = f"Problem: {problem} Solution: {solution} Is this solution correct for the problem? Reply only yes or no."
messages = [{"role": "user", "content": question}]

response = client.chat.completions.create(
    model="gemini-3.6-flash",
    messages=messages
)

check = response.choices[0].message.content

print(check)
# Out:
# yes

# %% [markdown]
# EXAMINER AND STUDENT'S QnA ROUND

# %%
examiner = [
    {"role": "system", "content": "You are an examiner. Ask one question at a time. After the student answers, score the answer out of 10 and then ask the next harder question."},
    {"role": "user", "content": "Start the examination"}
]

student = [{"role": "system", "content": "You are a student. Answer the examiner's question."}]

for i in range(3):

    response = client.chat.completions.create(
        model="gemini-3.5-flash-lite",
        messages=examiner
    )
    question = response.choices[0].message.content

    student.append({"role": "user", "content": question})

    response = client.chat.completions.create(
        model="gemini-3.5-flash-lite",
        messages=student
    )
    answer = response.choices[0].message.content

    student.append({"role": "assistant", "content": answer})
    examiner.append({"role": "assistant", "content": question})
    examiner.append({"role": "user", "content": answer})

    display(Markdown(f"**Examiner:** {question}\n\n**Student:** {answer}"))
# Out:
# **Examiner:** Welcome to the examination. Let's start with a foundational question to test your knowledge.
#
# **Question 1:**
# What is the powerhouse of the cell, and what is its primary function?
#
# **Student:** Hello!
#
# The powerhouse of the cell is the **mitochondria** (singular: mitochondrion). Its primary function is to generate most of the chemical energy needed to power the cell's biochemical reactions through the production of adenosine triphosphate (ATP), a process commonly known as cellular respiration.
# **Examiner:** **Score:** 10/10
#
# Excellent and precise answer.
#
# Let's step up the difficulty.
#
# **Question 2:**
# During cellular respiration, glucose is broken down to produce ATP. What are the three main stages of aerobic cellular respiration, and in which specific parts of the cell does each stage take place?
#
# **Student:** Thank you! I'm ready for the next question.
#
# ...

# %% [markdown]
# CV CHAT-BOT

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

load_dotenv(override=True)

openai = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

reader = PdfReader("my_cv/CV_Maitri_Pathak.pdf")
cv = ""

for page in reader.pages:
    text = page.extract_text()
    if text:
        cv += text

print(cv)
# Out:
# CURRICULUM VITAE
#  Maitri Pathak
#  Aspiring Computer Science Engineer
#  Sahayognagar, Talawade Road, Pune, India • +91-8446057030 • maitri.pathak2007@gmail.com
#  Motivated and disciplined Second Year B.Tech student, actively building technical skills and
#  maintaining a strong academic score.
# 1 PERSONAL INFORMATION
# Name
# Maitri Pathak
# Nationality
# Indian
# Address
# Sahayognagar, Talawade Road, Pune, India
# Telephone
# +91-8446057030
# E-mail
# maitri.pathak2007@gmail.com
# Present Position
# Second Year B.Tech Student, Pimpri Chinchwad University, Pune, India
# Field of Interest
# Computer Science & Engineering
# 2 ACADEMIC BACKGROUND
# 2025 – 2029
# Bachelor of Technology (B.Tech.), Computer Science & Engineering
# Pimpri Chinchwad University, Pune, India
# CGPA (1st Year): 9.93 / 10.00
# Semester-wise SGPA:
# Semester
# SGPA
# Semester 1
# 9.86
# Semester 2
# 10.00
# 2025
# 12th Grade, CBSE
# Cambridge International School and Junior College, Pune · Scored 85.8%
# ...

# %%
name = "Maitri Pathak"

system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible.  \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## {name}'s CV:\n{cv}\n\n"

system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Maitri Pathak. You are answering questions on Maitri Pathak's website, particularly questions related to Maitri Pathak's career, background, skills and experience. Your responsibility is to represent Maitri Pathak for interactions on the website as faithfully as possible.  Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Maitri Pathak's CV:\nCURRICULUM VITAE\n Maitri Pathak\n Aspiring Computer Science Engineer\n Sahayognagar, Talawade Road, Pune, India • +91-8446057030 • maitri.pathak2007@gmail.com\n Motivated and disciplined Second Year B.Tech student, actively building technical skills and\n maintaining a strong academic score.\n1 PERSONAL INFORMATION\nName\nMaitri Pathak\nNationality\nIndian\nAddress\nSahayognagar, Talawade Road, Pune, India\nTelephone\n+91-8446057030\nE-mail\nmaitri.pathak2007@gmail.com\nPresent Position\nSecond Year B.Tech Student, Pimp
# ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}] #history from gradio added
    response = openai.chat.completions.create(model="gemini-3.6-flash", messages=messages)
    return response.choices[0].message.content

gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from pydantic import BaseModel  # for defining structured data models

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website"

evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-3.5-flash-lite", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gemini-3.5-flash-lite", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# "No, I don't hold any patents at the moment. My current focus is on building my academic foundation in Computer Science & Engineering at Pimpri Chinchwad University, gaining practical experience through internships and hackathons, and developing innovative projects like student healthcare AI and safety tools. \n\nIs there a specific project or area of technology you'd like to discuss?"

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The agent correctly answered that she does not hold a patent based on the provided CV, stayed in character as Maitri Pathak, maintained a professional and engaging tone, and appropriately highlighted relevant projects from her background.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gemini-3.6-flash", messages=messages)
    return response.choices[0].message.content

def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gemini-3.6-flash", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# CV CHAT BOT USING PUSHOVER

# %%
from dotenv import load_dotenv
from openai import OpenAI
import json
import os
import requests
from pypdf import PdfReader
import gradio as gr

load_dotenv(override=True)
openai = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)
pushover_user = os.getenv("PUSHOVER_USER")
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_url = "https://api.pushover.net/1/messages.json"

if pushover_user:
    print(f"Pushover user found and starts with {pushover_user[0]}")
else:
    print("Pushover user not found")

if pushover_token:
    print(f"Pushover token found and starts with {pushover_token[0]}")
else:
    print("Pushover token not found")
# Out:
# Pushover user found and starts with u
# Pushover token found and starts with a

# %%
def push(message):
    print(f"Push: {message}")

    payload = {
        "user": pushover_user,
        "token": pushover_token,
        "message": message
    }
    requests.post(pushover_url, data=payload)
push("Life is simple!!")
# Out:
# Push: Life is simple!!

# %%
def record_user_details(email, name="Name not provided", notes="not provided"):
    push(f"Recording interest from {name} with email {email} and notes {notes}") 
    return {"recorded": "ok"}

def record_unknown_question(question):
    push(f"Recording {question} asked that I couldn't answer") 
    return {"recorded": "ok"}

record_user_details_json = {
    "name": "record_user_details",
    "description": "Use this tool to record that a user is interested in being in touch and provided an email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {
                "type": "string",
                "description": "The email address of this user"
            },
            "name": {
                "type": "string",
                "description": "The user's name, if they provided it"
            }
            ,
            "notes": {
                "type": "string",
                "description": "Any additional information about the conversation that's worth recording to give context"
            }
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

record_unknown_question_json = {
    "name": "record_unknown_question",
    "description": "Always use this tool to record any question that couldn't be answered as you didn't know the answer",
    "parameters": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "The question that couldn't be answered"
            },
        },
        "required": ["question"],
        "additionalProperties": False
    }
}

tools = [{"type": "function", "function": record_user_details_json},
        {"type": "function", "function": record_unknown_question_json}]

[{'type': 'function',
  'function': {'name': 'record_user_details',
   'description': 'Use this tool to record that a user is interested in being in touch and provided an email address',
   'parameters': {'type': 'object',
    'properties': {'email': {'type': 'string',
      'description': 'The email address of this user'},
     'name': {'type': 'string',
      'description': "The user's name, if they provided it"},
     'notes': {'type': 'string',
      'description': "Any additional information about the conversation that's worth recording to give context"}},
    'required': ['email'],
    'additionalProperties': False}}},
 {'type': 'function',
  'function': {'name': 'record_unknown_question',
   'description': "Always use this tool to record any question that couldn't be answered as you didn't know the answer",
   'parameters': {'type': 'object',
    'properties': {'question': {'type': 'string',
      'description': "The question that couldn't be answered"}},
    'required': ['question'],
    'additionalProperties': False}}}]

def handle_tool_calls(tool_calls): # runs the requested tool (by name) and returns results for the model
    results = []  
    for tool_call in tool_calls:
        tool_name = tool_call.function.name 
        arguments = json.loads(tool_call.function.arguments) 
        print(f"Tool called: {tool_name}", flush=True) 

        if tool_name == "record_user_details": 
            result = record_user_details(**arguments) 
        elif tool_name == "record_unknown_question": 
            result = record_unknown_question(**arguments) 

        results.append({"role": "tool","content": json.dumps(result),"tool_call_id": tool_call.id})
    return results

globals()["record_unknown_question"]("this is a really hard question")
# Out:
# Push: Recording this is a really hard question asked that I couldn't answer
# {'recorded': 'ok'}

# %%
def handle_tool_calls(tool_calls):  # runs each tool the model requested and returns their results
    results = []

    for tool_call in tool_calls:
        tool_name = tool_call.function.name
        arguments = json.loads(tool_call.function.arguments)
        print(f"Tool called: {tool_name}", flush=True)
        tool = globals().get(tool_name)
        result = tool(**arguments) if tool else {}

        results.append({
            "role": "tool",
            "content": json.dumps(result),
            "tool_call_id": tool_call.id
        })
    return results

reader = PdfReader("my_cv/CV_Maitri_Pathak.pdf")
cv = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        cv += text

name = "Maitri Pathak"

system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible.  \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## {name}'s CV:\n{cv}\n\n"

system_prompt += f"With this context, please chat with the user, always staying in character as {name}."


def chat(message, history): # handles a chat turn, looping until the model gives a final (non-tool) answer
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    done = False
    while not done: 
        response = openai.chat.completions.create(model="gemini-3.5-flash-lite", messages=messages, tools=tools)
        finish_reason = response.choices[0].finish_reason
        
        if finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_calls = message.tool_calls
            results = handle_tool_calls(tool_calls) 
            messages.append(message)
            messages.extend(results)
        else:
            done = True
    return response.choices[0].message.content

gr.ChatInterface(chat).launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://0fe7c0ea85149b6fcc.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0fe7c0ea85149b6fcc.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Tool called: record_unknown_question
# Push: Recording Your PhD plans? asked that I couldn't answer
# Tool called: record_user_details
# Push: Recording interest from Name not provided with email satya@gmail.com and notes User provided email to stay in touch, discussed PhD plans and future goals.

# %% [markdown]
# ### DEPLOYING THE CHATBOT USING RENDER
#
# #### 1. Two required code changes before deploying
#
# **a) Remove `share=True` and bind to Render's port/host**
#
# Render runs your app in a container and routes traffic to it — `share=True` (Gradio's public tunnel link) isn't needed and won't work reliably there. Replace the last line:
#
# ```python
# gr.ChatInterface(chat).launch(
#     server_name="0.0.0.0",
#     server_port=int(os.environ.get("PORT", 7860))
# )
# ```
# Render assigns a random port via the `PORT` environment variable — your app must read it dynamically rather than hardcoding one.
#
# **b) Make sure your CV PDF is included in the upload**
#
# Your code loads:
# reader = PdfReader("my_cv/CV_Maitri_Pathak.pdf")
#
# Make sure the `my_cv/` folder and PDF are uploaded to GitHub too — otherwise this line will crash on Render since the file won't exist.
#
#
# #### 2. Project structure
#
# ```
# cv-chatbot/
# │
# ├── cv_chatbot.py          # main app
# ├── requirements.txt       # dependencies
# ├── .gitignore              # excludes .env, cache files
# │
# └── my_cv/
#     └── CV_Maitri_Pathak.pdf
# ```
#
#
# #### 3. Create `requirements.txt`
# Based on your imports, create a file named `requirements.txt` with:
# python-dotenv
# openai
# requests
# pypdf
# gradio
#
#
# #### 4. Environment variables
# Your code expects these — do NOT upload them in a `.env` file to GitHub. Set them in Render's dashboard instead (Step 7):
# - `GOOGLE_API_KEY` — your Gemini API key (used via the OpenAI-compatible endpoint)
# - `PUSHOVER_USER` — your Pushover user key
# - `PUSHOVER_TOKEN` — your Pushover app token
#
# Create a `.gitignore` file with:
# .env
# pycache/
# *.pyc
#
#
# #### 5. Set the start command
# Since this is a plain Python script that calls `.launch()` itself, the start command is just:
# python cv_chatbot.py
#
#
# #### 6. Upload your project to GitHub (no terminal needed)
# 1. Go to [github.com](https://github.com) and log in
# 2. Click the **+** icon (top right) → **New repository**
# 3. Name it (e.g. `cv-chatbot`), keep it Public or Private, click **Create repository**
# 4. On the new repo page, click **uploading an existing file** (or **Add file → Upload files**)
# 5. Drag and drop your project files: `cv_chatbot.py`, `requirements.txt`, `.gitignore`, and the `my_cv` folder (with the PDF inside)
# 6. Scroll down and click **Commit changes**
#
#
# #### 7. Create a new Web Service on Render
# 1. Go to [render.com](https://render.com) and sign in
# 2. Click **New +** → **Web Service**
# 3. Connect your GitHub account and select the repo you just created
# 4. Configure:
#    - **Runtime:** Python 3
#    - **Build Command:** `pip install -r requirements.txt`
#    - **Start Command:** `python cv_chatbot.py`
#
#
# #### 8. Add environment variables
# In your service → **Environment** tab, add:
# - `GOOGLE_API_KEY`
# - `PUSHOVER_USER`
# - `PUSHOVER_TOKEN`
#
#
# #### 9. Deploy and test
# Click **Create Web Service**. Once live, Render gives you a URL like `https://cv-chatbot.onrender.com` — open it and confirm the Gradio chat UI loads and responds.
